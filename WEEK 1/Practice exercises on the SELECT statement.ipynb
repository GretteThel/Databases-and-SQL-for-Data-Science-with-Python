# %% [markdown]
# ## Practice exercises on the SELECT statement

# %% [markdown]
# 1. Retrieve the fun facts and filming locations of all films.

# %% [markdown]
# <details><summary>Click here for a hint</summary>
#
# ```python
# Follow example 2 of SELECT, where records containing details of some particular columns have been retrieved.
# ```
#
# </details>

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# SELECT Locations, FunFacts FROM FilmLocations;
# ```
#
# </details>

# %% [markdown]
# <details><summary>Click here for the output</summary>
#
# ```python
# refer to the image
# ```
#
# </details>

# %%
from IPython.display import display, Image

# Specify the correct path to the image file
image_path = r"C:\Users\greth\OneDrive\Desktop\IBM Z AMBASSADOR\COURSERA\DATA ENGINEER\DATABASES AND SQL WITH PYTHON\output1.png"

# Display the image
display(Image(filename=image_path, width=1000))

# %%
from IPython.display import display, Image

# Specify the path to the image file
image_path = r"C:\Users\greth\OneDrive\Desktop\IBM Z AMBASSADOR\COURSERA\DATA ENGINEER\DATABASES AND SQL WITH PYTHON\output1.png"

# Display the image
display(Image(filename=image_path, width=1000))

# %% [markdown]
# 2. Retrieve the names of all films released in the 20th century and before (release years before 2000 including 2000), along with filming locations and release years.

# %% [markdown]
# <details><summary>Click here for a hint</summary>
#
# ```python
# Follow example 3 of SELECT, where we restricted the output resultset to retrieve only the film records with certain release years. Use WHERE clause comparison operator <=, which means Less than or equal to.
# ```
#
# </details>

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# SELECT Title, ReleaseYear, Locations FROM FilmLocations WHERE ReleaseYear<=2000;
# ```
#
# </details>

# %% [markdown]
# <details><summary>Click here for the output</summary>
#
# ```python
# refer to the image
# ```
#
# </details>

# %%
from IPython.display import display, Image

# Specify the path to the image file
image_path = r"C:\Users\greth\OneDrive\Desktop\IBM Z AMBASSADOR\COURSERA\DATA ENGINEER\DATABASES AND SQL WITH PYTHON\output2.png"

# Display the image
display(Image(filename=image_path, width=1000))

# %%
<details><summary>Click here for a hint</summary>

```python
Use WHERE clause comparison operator <>, which means Not equal to.
```

</details>

# %%
from IPython.display import display, HTML

# HTML code with formatting
html_code = """
<details>
    <summary><a href="javascript:code_toggle()">Click here for a hint</a></summary>
    <div style="font-weight: bold; border: 1px solid black; padding: 5px; display: inline-block;">&lt;&gt;</div>
    <p>Use WHERE clause comparison operator &lt;&gt;, which means <strong>Not equal to</strong>.</p>
    <script>
        function code_toggle() {
            var code_cells = document.getElementsByClassName('code_cell');
            for (var i = 0; i < code_cells.length; i++) {
                var cell = code_cells[i];
                var display_value = cell.style.display === '' ? 'none' : '';
                cell.style.display = display_value;
            }
        }
    </script>
</details>
"""

# Display the HTML code
display(HTML(html_code))
# Out:
# <details>
#     <summary><a href="javascript:code_toggle()">Click here for a hint</a></summary>
#     <div style="font-weight: bold; border: 1px solid black; padding: 5px; display: inline-block;">&lt;&gt;</div>
#     <p>Use WHERE clause comparison operator &lt;&gt;, which means <strong>Not equal to</strong>.</p>
#     <script>
#         function code_toggle() {
#             var code_cells = document.getElementsByClassName('code_cell');
#             for (var i = 0; i < code_cells.length; i++) {
#                 var cell = code_cells[i];
#                 var display_value = cell.style.display === '' ? 'none' : '';
#                 cell.style.display = display_value;
#             }
#         }
#     </script>
# </details>

# %%
from IPython.display import display, Image

# Specify the correct path to the image file
image_path = r"C:\Users\greth\OneDrive\Desktop\IBM Z AMBASSADOR\COURSERA\DATA ENGINEER\DATABASES AND SQL WITH PYTHON\output2.png"

# Display the image
display(Image(filename=image_path, width=1000))

# %% [markdown]
# 3. Retrieve the names, production company names, filming locations, and release years of the films not written by James Cameron.

# %% [markdown]
# <details><summary>Click here for a hint</summary>
#
# ```python
# Use WHERE clause comparison operator <>, which means Not equal to..
# ```
#
# </details>

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# SELECT Title, ProductionCompany, Locations, ReleaseYear FROM FilmLocations WHERE Writer<>"James Cameron";
# ```
#
# </details>

# %% [markdown]
# <details><summary>Click here for a hint</summary>
#
# ```python
# refer to the image
# ```
#
# </details>

# %%
from IPython.display import display, Image

# Specify the correct path to the image file
image_path = r"C:\Users\greth\OneDrive\Desktop\IBM Z AMBASSADOR\COURSERA\DATA ENGINEER\DATABASES AND SQL WITH PYTHON\output2.png"

# Display the image
display(Image(filename=image_path, width=1000))

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Congratulations on completing this lab!
#
# You are now able to:
#
#    * Query a database using SELECT statements
#    * Retrieve all or selected columns of data
#    * Filter the query response to meet a defined criteria

# %% [markdown]
# # Author(s)
#
# Sandip Saha Joy
#
# # Other Contributor(s)
#
# Abhishek Gagneja

# %% [markdown]
# ## Change Log
#
# | Date (YYYY-MM-DD) | Version | Changed By                    | Change Description                 |
# | ----------------- | ------- | ----------------------------- | ---------------------------------- |
# | 2023-10-12        | 1.9     | Mercedes Schneiderhek         | QA Pass w/Edits                    |
# | 2023-10-11        | 1.8 	  |Misty Taylor                   | ID Check	                       |
# | 2023-10-01        | 1.7 	  |Abhishek Gagneja               |	Updated Lab instructions           |
# | 2023-07-11        | 1.6  	  |Lakshmi Holla 	              |Updated labs                        |
# | 2023-06-02        |1.5 	  |Eric Hao 	                  |Fixed Page Styles                   |
# | 2023-05-10        |1.4 	  |Eric Hao & Vladislav Boyko     |Updated Page Frames                 |
# |2023-05-04         |1.3 	  |Benny Li 	                  |Republished                         |
# |2022-07-27 	    |1.2 	  |Lakshmi Holla 	              |Updated html tag                    |
# |2020-11-23 	    |1.1 	  |Steve Ryan 	                  |ID Review                           |
# |2020-11-20         |1.0 	  |Sandip Saha Joy                |Initial version created             |
#
# <hr/>
#
# ## <h3 align="center"> © IBM Corporation 2023. All rights reserved. <h3/>
